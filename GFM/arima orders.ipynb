# %%
import pandas as pd
import numpy as np
# %matplotlib inline


## non  stationary dataset
df2 = pd.read_csv("Data/airline_passengers.csv", index_col = 'Month', parse_dates = True)

## stationary dataset 
df1 = pd.read_csv("Data/DailyTotalFemaleBirths.csv", index_col = 'Date', parse_dates = True)

# %%
# ! pip install pmdarima

# %%
from pmdarima import auto_arima

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
# help(auto_arima)

# %%
step_wisefit = auto_arima(df1['Births'],start_p= 0, max_p=6, start_q = 0, max_q = 3, trace= True)#, seasonal = False)
# seasonal false helps our model to avoid the seasonal componenets , using eda we alreasy know there is no seasonality
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2650.760, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2565.234, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2463.584, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2648.768, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2460.154, Time=0.11 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2461.271, Time=0.20 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=2460.722, Time=0.17 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=2536.154, Time=0.11 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2463.000, Time=0.48 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=2459.074, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=2462.221, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=2563.261, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=2460.367, Time=0.13 sec
# ...

# %%
step_wisefit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  365
# Model:               SARIMAX(1, 1, 1)   Log Likelihood               -1226.537
# Date:                Mon, 23 Sep 2024   AIC                           2459.074
# Time:                        13:28:42   BIC                           2470.766
# Sample:                    01-01-1959   HQIC                          2463.721
#                          - 12-31-1959
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1252      0.060      2.097      0.036       0.008       0.242
# ma.L1         -0.9624      0.017    -56.429      0.000      -0.996      -0.929
# sigma2        49.1512      3.250     15.122      0.000      42.781      55.522
# ...

# %%
# on non stationary data
stepwise_fit = auto_arima(df2['Thousands of Passengers'],start_p = 0 
                          , max_p = 4, start_q= 0, max_q = 4,trace=True,seasonal = True, m = 12)
#m refers to the periods in a  season
# since we have monthly data 
# if quarterly data = 4
# annual data = 1
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=1032.128, Time=0.12 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1031.508, Time=0.03 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1020.393, Time=0.07 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=1021.003, Time=0.07 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=1020.393, Time=0.03 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=1019.239, Time=0.14 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=0.59 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=1020.493, Time=0.14 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=1032.120, Time=0.07 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=1021.120, Time=0.14 sec
#  ARIMA(1,1,1)(2,1,0)[12]             : AIC=1021.032, Time=0.20 sec
#  ARIMA(0,1,1)(2,1,0)[12]             : AIC=1019.178, Time=0.15 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=1020.425, Time=0.07 sec
# ...

# %%
# for seasonal data provide seasonal = True 
# to do seasonal differencing we need to specify m also

# %%
stepwise_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...
# Dep. Variable:                                   y   No. Observations:                  144
# Model:             SARIMAX(0, 1, 1)x(2, 1, [], 12)   Log Likelihood                -505.589
# Date:                             Mon, 23 Sep 2024   AIC                           1019.178
# Time:                                     13:28:45   BIC                           1030.679
# Sample:                                 01-01-1949   HQIC                          1023.851
#                                       - 12-01-1960
# Covariance Type:                               opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.3634      0.074     -4.945      0.000      -0.508      -0.219
# ...
