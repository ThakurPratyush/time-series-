# %%
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv("df1.csv", index_col= 0)
# frst col taken as index
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv("df2.csv")
df2.head()
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y

# %%
# last col is the categorical  type

# %%
df1['A'].plot.hist()
# shows dis of values in a columns
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.hist(edgecolor = 'k', bins = 20).autoscale(enable = True, axis = 'both', tight = True)
# edgecolor can be given with single char color code , making boundaries of plot of a particular color
# autoscale helps us to scale the x and y axis in a way so that the graph is very tight to the boundaries
# axis = 'both' would help to do same for both axis
# sometime to get better idea of data we might have to increase num of bins

# %%
# if we want a grid to assist us to get the counts
df1['A'].plot.hist(grid = True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y
# 5  0.286043  0.593465  0.907307  0.637898  x
# 6  0.430436  0.166230  0.469383  0.497701  z
# 7  0.312296  0.502823  0.806609  0.850519  z
# 8  0.187765  0.997075  0.895955  0.530390  x
# 9  0.908162  0.232726  0.414138  0.432007  y

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
# by default index is taken as the categoiral variable
# wrt to this variable value of rest of variables would be shown 
# ex at index 0 value of a is 0.03 and similaryly for all the b, c,d variables
# e being other categorical var is simply ignored

# %%
df2.plot.bar(stacked = True)
#barh for horizaontal bar
# Out:
# <Axes: >

# %%
df2.plot.line(y = ['a','b','c'], figsize = (10,4), lw =4 )
# Out:
# <Axes: >

# %%
df2.plot.area(y = ['a','b','c'], figsize = (10,4), lw =4 ,alpha = 0.4,stacked = False)
# Out:
# <Axes: >

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
# checking the dependence of one variable to another : scatter plot
df1.plot.scatter(x= 'A',y ='B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x= 'A',y ='B', c ='C',cmap = 'coolwarm')

# Color gradient (from blue to red) visually represents the range of values in 'C'
# , helping you to easily identify patterns or clusters based on the third dimension of data.
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y ='B', s = df1['C']*50, alpha = 0.3)
# Out:
# C:\Users\thaku\anaconda3\lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
# larger c valye larger the bubble

# %%
df1.plot.scatter(x='A', y ='B', s = df1['C']*50, c = 'D', alpha = 0.3, cmap ='coolwarm')
# Out:
# C:\Users\thaku\anaconda3\lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
df2
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y
# 5  0.286043  0.593465  0.907307  0.637898  x
# 6  0.430436  0.166230  0.469383  0.497701  z
# 7  0.312296  0.502823  0.806609  0.850519  z
# 8  0.187765  0.997075  0.895955  0.530390  x
# 9  0.908162  0.232726  0.414138  0.432007  y

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df2.boxplot()
# Out:
# <Axes: >

# %%
# no diff except grid

# %%
# shows dis of columns

# %%
df2['a'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df2.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
import numpy as np
df = pd.DataFrame(np.random.randn(1000,2), columns = ['A','B'])

# %%
df.plot.scatter('A','B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# NOT ABLE to understand how many points are ina  way overlaping each other
df.plot.hexbin(x = 'A',y = 'B', gridsize = 25,cmap = 'coolwarm')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# grid size allows us to scale the size of drawn hexagona
## most of the points are lying near where both a adn b are 0 (true since norm dist)

# %%
df2.plot()
# def is a line plot
# Out:
# <Axes: >

# %%
df2['c'].plot.line(figsize = (20,3),ls = '--', c ='red', lw = 5)
 # -.   : 
# color can be hex or codes
# Out:
# <Axes: >

# %%
title = "PLOT TITLE"
xlabel = "X label"
ylabel = "Y label"
ax = df2['c'].plot.line(figsize = (20,3),ls = '--', c ='red', lw = 5, title = title)
ax.set(xlabel = xlabel, ylabel = ylabel)
# Out:
# [Text(0.5, 0, 'X label'), Text(0, 0.5, 'Y label')]

# %%
ax = df2.plot()
# ax.legend(loc = 5)
ax.legend(loc = 0 , bbox_to_anchor = (1.0,1.0))
# gap from legend to graph

# %%
# Outside plot
